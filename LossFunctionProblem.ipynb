# %% [markdown]
# <a href="https://colab.research.google.com/github/JayNguyen14/shiny-memory_ML/blob/main/LossFunctionProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 5.2
# The loss $L$ for binary classification for a single training pair ${x,y}$ is:
# $$L = -(1-y)\log{[1-sig[f[x,\phi]]]} - y~\log{sig[f[x,\phi]]]}$$
